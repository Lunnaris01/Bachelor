# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
array = np.loadtxt("saves/breakout/final_R2_final/reward.out")[0:250]
array1 = np.loadtxt("saves/breakout/final_R2_drittel/reward.out")[0:]
array2 = np.loadtxt("saves/breakout/final_R4_final/reward.out")[0:250]
array3 = np.loadtxt("saves/breakout/final_R4_drittel/reward.out")[0:]
print(array.shape,array1.shape,array2.shape,array3.shape)
x_0 = np.linspace(0,250000,array.shape[0])
x_1 = np.linspace(0,250000,array1.shape[0])
x_2 = np.linspace(0,250000,array2.shape[0])
x_3 = np.linspace(0,250000,array3.shape[0])
#x_4 = np.linspace(0,260000,array4.shape[0])
# Out:
# (250,) (354,) (250,) (336,)

# %%
l1, = plt.plot(x_0, array, label='Replay 2 (1)')
l2, = plt.plot(x_1, array1, label='Replay 2 (2)')
l3, = plt.plot(x_2, array2, label= 'Replay 4 (1)')
l4, = plt.plot(x_3, array3, label= 'Replay 4 (2)')
#l5, = plt.plot(x_4, array4, label= 'Replay twice with individual preprocessing')
plt.legend(handles=[l1, l2,l3, l4])

# %%
x_0 = np.linspace(0,250000,array.shape[0])
x_1 = np.linspace(0,(250000+250000/3),array1.shape[0])
x_2 = np.linspace(0,(250000+500000/3),array2.shape[0])
x_4 = np.linspace(0,(250000+1000000/3),array3.shape[0])

# %%
l1, =plt.plot(x_0,array, label='No replay')
l2, =plt.plot(x_1,array1, label='Replay once')
l3, =plt.plot(x_2,array2, label= 'Replay twice')
l4, =plt.plot(x_4,array3, label= 'Replay 4 times')
plt.legend(handles=[l1, l2,l3,l4])

# %%
array = np.loadtxt("saves/spaceinv/final_R0/reward.out")[10:]
array1 = np.loadtxt("saves/spaceinv/final_R1/reward.out")[10:]
array2 = np.loadtxt("saves/spaceinv/final_R2/reward.out")[10:]
array3 = np.loadtxt("saves/spaceinv/final_R4/reward.out")[10:]
print(array1.shape)
print(array.shape,array1.shape,array2.shape,array3.shape,array4.shape)
x_0 = np.linspace(0,250000,array.shape[0])
x_1 = np.linspace(0,250000,array1.shape[0])
x_2 = np.linspace(0,250000,array2.shape[0])
x_3 = np.linspace(0,250000,array3.shape[0])
l1, = plt.plot(x_0, array, label='No replay')
l2, = plt.plot(x_1, array1, label='Replay once')
l3, = plt.plot(x_2, array2, label= 'Replay twice')
l4, = plt.plot(x_3, array3, label= 'Replay 4 times')
#l5, = plt.plot(x_4, array4, label= 'replay twice with prepro')
plt.legend(handles=[l1, l2,l3,l4])
# Out:
# (268,)
# (304,) (268,) (259,) (261,) (280,)

# %%
x_0 = np.linspace(0,250000,array.shape[0])
x_1 = np.linspace(0,(250000+250000/3),array1.shape[0])
x_2 = np.linspace(0,(250000+500000/3),array2.shape[0])
x_4 = np.linspace(0,(250000+1000000/3),array3.shape[0])
l1, =plt.plot(x_0,array, label='No replay')
l2, =plt.plot(x_1,array1, label='Replay once')
l3, =plt.plot(x_2,array2, label= 'Replay twice')
l4, =plt.plot(x_4,array3, label= 'Replay 4 times')
plt.legend(handles=[l1, l2,l3,l4])

# %%
import tensorflow as tf
# Out:
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
array = np.loadtxt("saves/breakout/final_R0_2/reward.out")[0:250]
array1 = np.loadtxt("saves/breakout/final_R2_final/reward.out")[0:250]
array2 = np.loadtxt("saves/breakout/final_R2_drittel/reward.out")[0:]
array3 = np.loadtxt("saves/breakout/final_R4_final/reward.out")[0:250]
array4 = np.loadtxt("saves/breakout/final_R4_drittel/reward.out")[0:]
print(array1.shape)
print(array.shape,array1.shape,array2.shape,array3.shape)
x_0 = np.linspace(0,250000,array.shape[0])
x_1 = np.linspace(0,250000,array1.shape[0])
x_2 = np.linspace(0,250000,array2.shape[0])
x_3 = np.linspace(0,250000,array3.shape[0])
x_4 = np.linspace(0,250000,array4.shape[0])
l1, = plt.plot(x_0, array, label='No replay')
l2, = plt.plot(x_1, array1, label='Replay twice (1)', color='g',linestyle = '-')
l3, = plt.plot(x_2, array2, label= 'Replay twice (2)', color='g',linestyle = ':')
l4, = plt.plot(x_3, array3, label= 'Replay 4 times (1)', color='r',linestyle = '-')
l5, = plt.plot(x_4, array4, label= 'Replay 4 times (2)',color='r',linestyle = ':')

#l5, = plt.plot(x_4, array4, label= 'replay twice with prepro')
plt.legend(handles=[l1, l2,l3,l4,l5])
# Out:
# (250,)
# (250,) (250,) (354,) (250,)

# %%
x_0 = np.linspace(0,250000,array.shape[0])
x_1 = np.linspace(0,250000+(500000/3),array1.shape[0])
x_2 = np.linspace(0,250000+(500000/3),array2.shape[0])
x_3 = np.linspace(0,250000+(1000000/3),array3.shape[0])
x_4 = np.linspace(0,250000+(1000000/3),array4.shape[0])
l1, = plt.plot(x_0, array, label='No replay')
l2, = plt.plot(x_1, array1, label='Replay twice (1)', color='g',linestyle = '-')
l3, = plt.plot(x_2, array2, label= 'Replay twice (2)', color='g',linestyle = ':')
l4, = plt.plot(x_3, array3, label= 'Replay 4 times (1)', color='r',linestyle = '-')
l5, = plt.plot(x_4, array4, label= 'Replay 4 times (2)',color='r',linestyle = ':')
plt.legend(handles=[l1, l2,l3,l4,l5])

# %%
array = np.loadtxt("saves/seaquest/final_R2/reward.out")[10:]
array1 = np.loadtxt("saves/seaquest/S0/reward.out")[10:]
array2 = np.loadtxt("saves/seaquest/S1/reward.out")[10:]

x_0 = np.linspace(0,250000,array2.shape[0])
x_1 = np.linspace(0,250000,array1.shape[0])
x_2 = np.linspace(0,250000,array.shape[0])
l1, = plt.plot(x_2, array, label='1')
l2, = plt.plot(x_1, array1, label='2')
l3, = plt.plot(x_0, array2, label= '3')
#l5, = plt.plot(x_4, array4, label= 'replay twice with prepro')
plt.legend(handles=[l1, l2, l3])
