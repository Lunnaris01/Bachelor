# %%
import numpy as np

array = np.loadtxt("saves/breakout/final_R0_2/reward.out")
array1 = np.loadtxt("saves/breakout/final_R1_final/reward.out")
array2 = np.loadtxt("saves/breakout/final_R2_final/reward.out")
array3 = np.loadtxt("saves/breakout/final_R4_final/reward.out")
print(array1.shape)
# Out:
# (905,)

# %%
import matplotlib.pyplot as plt
plt.plot(array)
plt.plot(array1)
plt.plot(array2)
plt.plot(array3)

# %%
x_0 = np.linspace(0,1000000,array.shape[0])
x_1 = np.linspace(0,2000000,array1.shape[0])
x_2 = np.linspace(0,3000000,array2.shape[0])
x_4 = np.linspace(0,5000000,array3.shape[0])

# %%
plt.plot(x_0,array)
plt.plot(x_1,array1)
plt.plot(x_2,array2)
plt.plot(x_4,array3)
